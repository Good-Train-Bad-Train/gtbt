# %% [markdown]
# holidays

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import re
import datetime as dt

# %%
df = pd.read_csv("../data/holidays.csv")

# %%
df
# Out:
#    nat. holidays since Dec2019 related brueckentage 2019      bayern  \
# 0                   2019-12-24                2019-12-27  2020-01-06
# 1                   2019-12-25                2020-05-22  2020-08-08
# 2                   2019-12-26                2020-06-12  2020-08-15
# 3                   2020-01-01                2021-05-14  2021-01-06
# 4                   2020-04-10                2021-06-04  2022-01-06
# 5                   2020-04-12                2022-05-27  2022-08-08
# 6                   2020-05-01                2022-06-17  2022-08-15
# 7                   2020-05-21                       NaN         NaN
# 8                   2020-06-01                       NaN         NaN
# 9                   2020-06-11                       NaN         NaN
# 10                  2020-10-03                       NaN         NaN
# 11                  2020-11-01                       NaN         NaN
# 12                  2020-12-24                       NaN         NaN
# ...
