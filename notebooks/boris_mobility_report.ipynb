# %% [markdown]
# Google Mobility Report

# %%
import numpy as np
import pandas as pd
import re
import datetime as dt

# %%
df = pd.read_csv("../data/2020_DE_Region_Mobility_Report.csv")

# %%
df.shape
# Out:
# (5457, 15)

# %%
df.head(10)
# Out:
#   country_region_code country_region sub_region_1  sub_region_2  metro_area  \
# 0                  DE        Germany          NaN           NaN         NaN
# 1                  DE        Germany          NaN           NaN         NaN
# 2                  DE        Germany          NaN           NaN         NaN
# 3                  DE        Germany          NaN           NaN         NaN
# 4                  DE        Germany          NaN           NaN         NaN
# 5                  DE        Germany          NaN           NaN         NaN
# 6                  DE        Germany          NaN           NaN         NaN
# 7                  DE        Germany          NaN           NaN         NaN
# 8                  DE        Germany          NaN           NaN         NaN
# 9                  DE        Germany          NaN           NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# ...

# %%
# reduce columns
# df = df.drop(columns=[2,3,7])
df = df.drop('retail_and_recreation_percent_change_from_baseline',1)
df = df.drop('grocery_and_pharmacy_percent_change_from_baseline',1)
df= df.drop('parks_percent_change_from_baseline',1)
df=df.drop('workplaces_percent_change_from_baseline',1)
#only for NRW and BY
# Out:
# /var/folders/mv/43241nxd07z663ggm5_d6h8h0000gn/T/ipykernel_60357/1013799175.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('retail_and_recreation_percent_change_from_baseline',1)
# /var/folders/mv/43241nxd07z663ggm5_d6h8h0000gn/T/ipykernel_60357/1013799175.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('grocery_and_pharmacy_percent_change_from_baseline',1)
# /var/folders/mv/43241nxd07z663ggm5_d6h8h0000gn/T/ipykernel_60357/1013799175.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df= df.drop('parks_percent_change_from_baseline',1)
# ...

# %%
df.head(5)
# Out:
#   country_region_code country_region sub_region_1  sub_region_2  metro_area  \
# 0                  DE        Germany          NaN           NaN         NaN
# 1                  DE        Germany          NaN           NaN         NaN
# 2                  DE        Germany          NaN           NaN         NaN
# 3                  DE        Germany          NaN           NaN         NaN
# 4                  DE        Germany          NaN           NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJa76xwh5ymkcRW-WRjmtd6HU  2020-02-15
# 1             NaN               NaN  ChIJa76xwh5ymkcRW-WRjmtd6HU  2020-02-16
# 2             NaN               NaN  ChIJa76xwh5ymkcRW-WRjmtd6HU  2020-02-17
# 3             NaN               NaN  ChIJa76xwh5ymkcRW-WRjmtd6HU  2020-02-18
# 4             NaN               NaN  ChIJa76xwh5ymkcRW-WRjmtd6HU  2020-02-19
#
# ...
