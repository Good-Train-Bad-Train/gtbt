# %% [markdown]
# # GET WEATHER FORECAST DATA
#
# This functions store forecast data of 14 days in the future for the chosen train stations into a pickle file to later use it as database for the GTBT app call to our API.

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import pickle

# %%
def special_characters(city):
    if city == 'Munchen':
        return 'München'
    elif city == 'Koln':
        return 'Köln'
    elif city == 'Wurzburg':
        return 'Würzburg'
    elif city == 'Nurnberg':
        return 'Nürnberg'
    elif city == 'Gottingen':
        return 'Göttingen'
    else:
        return city
    
def weather_forecast(start_city, end_city, user_date):
    # get weather forecast
    key = 'xxxx' #Add here your own key from https://www.visualcrossing.com

    start_city =  special_characters(start_city)
    end_city = special_characters(end_city)
    
    start_date = pd.Timestamp(user_date).round('H')
    start_date_00 = pd.Timestamp(start_date.year, start_date.month, start_date.day)
    end_date = datetime.now() + timedelta(14)
    end_date_00 = pd.Timestamp(end_date.year, end_date.month, end_date.day) + timedelta(1) - timedelta(hours=1)

    start_date_str = datetime.strftime(start_date, '%Y-%m-%d')
    end_date_str = datetime.strftime(end_date, '%Y-%m-%d')

    stations_lat_lon = pd.read_csv('api/data/Deutsche_Bahn_Haltestellen.csv', usecols=['X', 'Y', 'NAME'])
    stations_name = ['Köln Hbf',
                    'München Hbf',
                    'Mannheim Hbf',
                    'Stuttgart Hbf',
                    'Würzburg Hbf',
                    'Frankfurt(Main)Hbf',
                    'Nürnberg Hbf',
                    'Essen Hbf',
                    'Hamburg Hbf',
                    'Berlin Hbf',
                    'Hannover Hbf',
                    'Hagen Hbf',
                    'Erfurt Hbf',
                    'Göttingen'
                    ]

    station_sc = [station for station in stations_name if start_city in station]
    station_ec = [station for station in stations_name if end_city in station]
    stations = station_sc + station_ec

    nodes = ['origin_city', 'destination_city']
    trip = {node: station for node, station in zip(nodes, stations)}
    hours = [6, 12]
    c_variables = ['temp', 'prcp', 'snow', 'wspd', 'wpgt', 'coco']

    coco_forecast = pd.read_csv('api/data/weather_coco_forecast.csv', sep=';')
    coco_forecast.set_index('Code', inplace=True)
    coco_forecast = coco_forecast.to_dict()['Weather Condition']

    new_classes_forecast = {
        1: [29, 42, 43],
        2: [2, 8, 9, 19, 20, 21, 24, 27, 28, 30, 31, 32, 33, 36, 38, 39, 40, 41],
        3: [1, 4, 6, 11, 12, 14, 18, 23, 26, 35, 37],
        4: [3, 5, 7, 10, 13, 15, 16, 17, 22, 25, 34]
    }

    db_path = 'raw_data/weather_forecast.pickle'
    with open(db_path, 'rb') as handle:
        weather_response = pickle.load(handle)
    
    weather = {}
    weather_dict = {}
    df = pd.DataFrame()
    for n, s in trip.items():
        lat = stations_lat_lon[stations_lat_lon['NAME'] == s]['Y'].mean()
        lon = stations_lat_lon[stations_lat_lon['NAME'] == s]['X'].mean()

        url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{str(lat)},{str(lon)}/{start_date_str}/{end_date_str}"
        params = {'key': key,
                'unitGroup': 'metric'}
        response = requests.get(url, params=params).json()

        weather_response[s] = response
        
        response = weather_response[s]
        
        number_of_days = (end_date - start_date).days + 1
        variables = ['datetime', 'temp', 'precip', 'snow', 'windspeed', 'windgust', 'conditions']
        sw_f = pd.DataFrame(columns=variables)
        sw_f['datetime'] = pd.date_range(start_date_00, end_date_00, freq='H')
        sw_f.set_index('datetime', inplace=True)

        for d in range(number_of_days):
            for i, r in sw_f.iterrows():
                for v in variables[1:]:
                    sw_f.loc[i, v] = response['days'][d]['hours'][i.hour][v]

        sw_f.rename(columns={'precip': 'prcp',
                            'windspeed': 'wspd',
                            'windgust': 'wpgt',
                            'conditions': 'coco'}, inplace=True)

        sw_f.index.names = ['time']

        weather[s] = sw_f.copy()

        weather[s]['coco'] = weather[s]['coco'].apply(lambda x: coco_func(x, coco_forecast, new_classes_forecast))
        weather[s].reset_index(inplace=True)
        weather[s]['time']  = pd.to_datetime(weather[s]['time'])

        if n == 'origin_city':
            nn = 'oc'
        elif n == 'destination_city':
            nn = 'dc'
        for h in hours:
            weather_dict['time_' + nn + ' -' + str(h) + 'H'] = weather[s][weather[s]['time'] == start_date - timedelta(hours=h)].rename(
                columns={'temp': 'temp_' + nn + '_' + str(h),
                            'prcp': 'prcp_' + nn + '_' + str(h),
                            'snow': 'snow_' + nn + '_' + str(h),
                            'wspd': 'wspd_' + nn + '_' + str(h),
                            'wpgt': 'wpgt_' + nn + '_' + str(h),
                            'coco': 'coco_' + nn + '_' + str(h)})

    total_df = pd.DataFrame()
    for k, v in weather_dict.items():
        v.reset_index(inplace=True)
        total_df[list(v.columns)[1:]] = v[list(v.columns)[1:]]

    for v in c_variables:
        total_df[v + '_max_combined'] = total_df[[v + '_oc_6', v + '_oc_12', v + '_dc_6', v + '_dc_12']].max(axis=1)

    total_df['temp_min_combined'] = total_df[['temp_oc_6', 'temp_oc_12', 'temp_dc_6', 'temp_dc_12']].min(axis=1)

    return total_df

def coco_func(x, coco_forecast, new_classes_forecast):
    x_list = x.split(', ')
    for k, v in coco_forecast.items():
        if v in x_list:
            for c, i in new_classes_forecast.items():
                if k in i:
                    return c

def get_weather_data(cities, user_date):

    start_date = pd.Timestamp(user_date).round('H')
    end_date = datetime.now() + timedelta(14)

    start_date_str = datetime.strftime(start_date, '%Y-%m-%d')
    end_date_str = datetime.strftime(end_date, '%Y-%m-%d')

    weather_response = {}
    for city in cities:
        key = '7DYDYYY5GVYHQA52HXFQV5A5Y'
        stations_lat_lon = pd.read_csv('api/data/Deutsche_Bahn_Haltestellen.csv', usecols=['X', 'Y', 'NAME'])
        lat = stations_lat_lon[stations_lat_lon['NAME'] == city]['Y'].mean()
        lon = stations_lat_lon[stations_lat_lon['NAME'] == city]['X'].mean()

        url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{str(lat)},{str(lon)}/{start_date_str}/{end_date_str}"
        params = {'key': key,
                'unitGroup': 'metric'}
        response = requests.get(url, params=params).json()

        weather_response[city] = response
        output_file = 'raw_data/weather_forecast.pickle'
        with open(output_file, 'wb') as handle:
            pickle.dump(weather_response, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
start_city = 'Koln'
end_city = 'Mannheim'
user_date = '2022-06-10 16:23:00'

total_df = weather_forecast(start_city, end_city, user_date)
total_df
# Out:
#                  time temp_oc_6 prcp_oc_6 snow_oc_6 wspd_oc_6 wpgt_oc_6  \
# 0 2022-06-10 04:00:00      21.4       0.0       0.0      18.0      26.8
#
#    coco_oc_6 temp_oc_12 prcp_oc_12 snow_oc_12  ... wspd_dc_12 wpgt_dc_12  \
# 0          1       15.8        0.0        0.0  ...        6.5        8.4
#
#    coco_dc_12 temp_max_combined prcp_max_combined snow_max_combined  \
# 0           1              22.9               0.0               0.0
#
#   wspd_max_combined wpgt_max_combined  coco_max_combined temp_min_combined
# 0              18.0              26.8                  1              15.8
#
# [1 rows x 32 columns]

# %%
db_path = 'raw_data/weather_forecast.pickle'
with open(db_path, 'rb') as handle:
    weather_response = pickle.load(handle)
weather_response['Mannheim Hbf']
# Out:
# {'queryCost': 1,
#  'latitude': 49.4793540000001,
#  'longitude': 8.46892100000002,
#  'resolvedAddress': '49.4793540000001,8.46892100000002',
#  'address': '49.4793540000001,8.46892100000002',
#  'timezone': 'Europe/Berlin',
#  'tzoffset': 2.0,
#  'description': 'Similar temperatures continuing with no rain expected.',
#  'days': [{'datetime': '2022-06-10',
#    'datetimeEpoch': 1654812000,
#    'tempmax': 24.6,
#    'tempmin': 7.6,
#    'temp': 18.0,
#    'feelslikemax': 24.6,
#    'feelslikemin': 7.6,
#    'feelslike': 18.0,
#    'dew': 10.1,
#    'humidity': 64.5,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 15.1,
#    'windspeed': 7.5,
#    'winddir': 199.2,
#    'pressure': 1022.7,
#    'cloudcover': 31.1,
#    'visibility': 16.9,
#    'solarradiation': 307.6,
#    'solarenergy': 26.6,
#    'uvindex': 9.0,
#    'severerisk': 10.0,
#    'sunrise': '05:20:01',
#    'sunriseEpoch': 1654831201,
#    'sunset': '21:31:33',
#    'sunsetEpoch': 1654889493,
#    'moonphase': 0.39,
#    'conditions': 'Partially cloudy',
#    'description': 'Becoming cloudy in the afternoon.',
#    'icon': 'partly-cloudy-day',
#    'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#    'source': 'comb',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1654812000,
#      'temp': 13.2,
#      'feelslike': 13.2,
#      'humidity': 85.92,
#      'dew': 10.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 4.7,
#      'windspeed': 4.9,
#      'winddir': 320.0,
#      'pressure': 1021.5,
#      'visibility': 10.0,
#      'cloudcover': 43.2,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU'],
#      'source': 'obs'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1654815600,
#      'temp': 12.6,
#      'feelslike': 12.6,
#      'humidity': 91.68,
#      'dew': 11.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 3.2,
#      'windspeed': 4.3,
#      'winddir': 360.0,
#      'pressure': 1022.0,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU'],
#      'source': 'obs'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1654819200,
#      'temp': 10.6,
#      'feelslike': 10.6,
#      'humidity': 95.69,
#      'dew': 9.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 3.2,
#      'windspeed': 1.8,
#      'winddir': 237.1,
#      'pressure': 1022.3,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU'],
#      'source': 'obs'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1654822800,
#      'temp': 9.9,
#      'feelslike': 9.5,
#      'humidity': 93.57,
#      'dew': 8.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 4.3,
#      'windspeed': 5.6,
#      'winddir': 314.0,
#      'pressure': 1022.3,
#      'visibility': 8.3,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU'],
#      'source': 'obs'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1654826400,
#      'temp': 10.9,
#      'feelslike': 10.9,
#      'humidity': 93.57,
#      'dew': 9.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 3.6,
#      'winddir': 0.0,
#      'pressure': 1022.0,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM'],
#      'source': 'obs'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1654830000,
#      'temp': 7.6,
#      'feelslike': 7.6,
#      'humidity': 100.0,
#      'dew': 7.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.4,
#      'windspeed': 2.4,
#      'winddir': 345.0,
#      'pressure': 1022.5,
#      'visibility': 7.6,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['ETAR', 'EDDF', 'ETOU'],
#      'source': 'obs'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1654833600,
#      'temp': 10.9,
#      'feelslike': 10.9,
#      'humidity': 93.59,
#      'dew': 9.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 5.4,
#      'winddir': 138.0,
#      'pressure': 1023.0,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 18.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1654837200,
#      'temp': 12.9,
#      'feelslike': 12.9,
#      'humidity': 87.72,
#      'dew': 10.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 10.8,
#      'windspeed': 5.4,
#      'winddir': 149.0,
#      'pressure': 1024.0,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 86.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1654840800,
#      'temp': 13.9,
#      'feelslike': 13.9,
#      'humidity': 82.17,
#      'dew': 11.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.2,
#      'windspeed': 4.0,
#      'winddir': 165.1,
#      'pressure': 1024.0,
#      'visibility': 10.0,
#      'cloudcover': 0.0,
#      'solarradiation': 214.0,
#      'solarenergy': 0.8,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1654844400,
#      'temp': 16.9,
#      'feelslike': 16.9,
#      'humidity': 67.84,
#      'dew': 11.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.6,
#      'windspeed': 5.4,
#      'winddir': 0.0,
#      'pressure': 1024.0,
#      'visibility': 10.0,
#      'cloudcover': 8.2,
#      'solarradiation': 427.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1654848000,
#      'temp': 18.9,
#      'feelslike': 18.9,
#      'humidity': 63.82,
#      'dew': 11.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.4,
#      'windspeed': 7.5,
#      'winddir': 157.0,
#      'pressure': 1024.0,
#      'visibility': 10.0,
#      'cloudcover': 8.2,
#      'solarradiation': 547.0,
#      'solarenergy': 2.0,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1654851600,
#      'temp': 20.0,
#      'feelslike': 20.0,
#      'humidity': 59.87,
#      'dew': 11.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.1,
#      'windspeed': 6.1,
#      'winddir': 176.5,
#      'pressure': 1024.0,
#      'visibility': 10.0,
#      'cloudcover': 8.2,
#      'solarradiation': 657.0,
#      'solarenergy': 2.4,
#      'uvindex': 7.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['ETAR', 'EDDF', 'ETOU', 'EDFM', 'C2091'],
#      'source': 'obs'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1654855200,
#      'temp': 21.7,
#      'feelslike': 21.7,
#      'humidity': 49.9,
#      'dew': 10.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.1,
#      'windspeed': 5.8,
#      'winddir': 181.4,
#      'pressure': 1024.0,
#      'visibility': 24.1,
#      'cloudcover': 28.5,
#      'solarradiation': 809.0,
#      'solarenergy': 2.9,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1654858800,
#      'temp': 22.7,
#      'feelslike': 22.7,
#      'humidity': 42.47,
#      'dew': 9.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.8,
#      'windspeed': 5.4,
#      'winddir': 207.9,
#      'pressure': 1024.0,
#      'visibility': 24.1,
#      'cloudcover': 71.0,
#      'solarradiation': 866.0,
#      'solarenergy': 3.1,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1654862400,
#      'temp': 23.3,
#      'feelslike': 23.3,
#      'humidity': 40.68,
#      'dew': 9.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.8,
#      'windspeed': 5.0,
#      'winddir': 215.5,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 56.2,
#      'solarradiation': 897.0,
#      'solarenergy': 3.2,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1654866000,
#      'temp': 24.0,
#      'feelslike': 24.0,
#      'humidity': 37.45,
#      'dew': 8.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.6,
#      'windspeed': 4.3,
#      'winddir': 208.3,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 66.5,
#      'solarradiation': 870.0,
#      'solarenergy': 3.1,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1654869600,
#      'temp': 24.2,
#      'feelslike': 24.2,
#      'humidity': 36.26,
#      'dew': 8.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.6,
#      'windspeed': 4.7,
#      'winddir': 218.5,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 83.0,
#      'solarradiation': 796.0,
#      'solarenergy': 2.9,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1654873200,
#      'temp': 24.6,
#      'feelslike': 24.6,
#      'humidity': 35.64,
#      'dew': 8.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.2,
#      'windspeed': 4.3,
#      'winddir': 217.7,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 63.3,
#      'solarradiation': 644.0,
#      'solarenergy': 2.3,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1654876800,
#      'temp': 24.5,
#      'feelslike': 24.5,
#      'humidity': 35.37,
#      'dew': 8.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.2,
#      'windspeed': 4.0,
#      'winddir': 212.4,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 91.3,
#      'solarradiation': 273.0,
#      'solarenergy': 1.0,
#      'uvindex': 3.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1654880400,
#      'temp': 24.1,
#      'feelslike': 24.1,
#      'humidity': 35.74,
#      'dew': 8.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 9.7,
#      'windspeed': 4.3,
#      'winddir': 214.9,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 75.5,
#      'solarradiation': 138.0,
#      'solarenergy': 0.5,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1654884000,
#      'temp': 23.6,
#      'feelslike': 23.6,
#      'humidity': 39.68,
#      'dew': 9.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 9.7,
#      'windspeed': 4.0,
#      'winddir': 199.6,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 40.7,
#      'solarradiation': 78.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1654887600,
#      'temp': 22.0,
#      'feelslike': 22.0,
#      'humidity': 54.11,
#      'dew': 12.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 2.2,
#      'winddir': 189.4,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 34.2,
#      'solarradiation': 57.0,
#      'solarenergy': 0.2,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1654891200,
#      'temp': 20.0,
#      'feelslike': 20.0,
#      'humidity': 59.99,
#      'dew': 12.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 13.0,
#      'windspeed': 7.2,
#      'winddir': 339.2,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 25.3,
#      'solarradiation': 5.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1654894800,
#      'temp': 18.8,
#      'feelslike': 18.8,
#      'humidity': 64.64,
#      'dew': 12.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.4,
#      'windspeed': 4.3,
#      'winddir': 13.4,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 43.8,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-06-11',
#    'datetimeEpoch': 1654898400,
#    'tempmax': 27.3,
#    'tempmin': 13.3,
#    'temp': 21.1,
#    'feelslikemax': 26.7,
#    'feelslikemin': 13.3,
#    'feelslike': 21.0,
#    'dew': 11.5,
#    'humidity': 59.1,
#    'precip': 0.0,
#    'precipprob': 9.5,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 20.9,
#    'windspeed': 9.7,
#    'winddir': 264.5,
#    'pressure': 1022.5,
#    'cloudcover': 32.6,
#    'visibility': 24.1,
#    'solarradiation': 311.6,
#    'solarenergy': 26.8,
#    'uvindex': 9.0,
#    'severerisk': 10.0,
#    'sunrise': '05:19:44',
#    'sunriseEpoch': 1654917584,
#    'sunset': '21:32:12',
#    'sunsetEpoch': 1654975932,
#    'moonphase': 0.44,
#    'conditions': 'Partially cloudy',
#    'description': 'Becoming cloudy in the afternoon.',
#    'icon': 'partly-cloudy-day',
#    'stations': None,
#    'source': 'fcst',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1654898400,
#      'temp': 17.9,
#      'feelslike': 17.9,
#      'humidity': 70.22,
#      'dew': 12.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 3.6,
#      'winddir': 347.4,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 33.6,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1654902000,
#      'temp': 16.7,
#      'feelslike': 16.7,
#      'humidity': 77.76,
#      'dew': 12.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 3.6,
#      'winddir': 325.4,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 22.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1654905600,
#      'temp': 15.8,
#      'feelslike': 15.8,
#      'humidity': 82.9,
#      'dew': 12.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 3.6,
#      'winddir': 299.0,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.9,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1654909200,
#      'temp': 15.3,
#      'feelslike': 15.3,
#      'humidity': 84.48,
#      'dew': 12.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.1,
#      'windspeed': 1.4,
#      'winddir': 284.6,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 1.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1654912800,
#      'temp': 14.7,
#      'feelslike': 14.7,
#      'humidity': 87.23,
#      'dew': 12.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 1.8,
#      'windspeed': 1.8,
#      'winddir': 346.2,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.5,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1654916400,
#      'temp': 13.7,
#      'feelslike': 13.7,
#      'humidity': 94.3,
#      'dew': 12.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 3.6,
#      'windspeed': 2.5,
#      'winddir': 349.6,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1654920000,
#      'temp': 13.3,
#      'feelslike': 13.3,
#      'humidity': 96.15,
#      'dew': 12.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 3.6,
#      'windspeed': 1.8,
#      'winddir': 336.5,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 1.6,
#      'solarradiation': 8.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1654923600,
#      'temp': 14.0,
#      'feelslike': 14.0,
#      'humidity': 91.87,
#      'dew': 12.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 2.5,
#      'windspeed': 1.4,
#      'winddir': 272.4,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 93.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1654927200,
#      'temp': 16.0,
#      'feelslike': 16.0,
#      'humidity': 80.78,
#      'dew': 12.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.0,
#      'windspeed': 1.8,
#      'winddir': 253.4,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 239.0,
#      'solarenergy': 0.9,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1654930800,
#      'temp': 18.6,
#      'feelslike': 18.6,
#      'humidity': 70.35,
#      'dew': 13.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.4,
#      'windspeed': 1.4,
#      'winddir': 183.4,
#      'pressure': 1024.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 402.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1654934400,
#      'temp': 21.1,
#      'feelslike': 21.1,
#      'humidity': 57.93,
#      'dew': 12.5,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 8.3,
#      'windspeed': 2.5,
#      'winddir': 162.2,
#      'pressure': 1024.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 560.0,
#      'solarenergy': 2.0,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1654938000,
#      'temp': 23.3,
#      'feelslike': 23.3,
#      'humidity': 46.81,
#      'dew': 11.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.5,
#      'windspeed': 4.0,
#      'winddir': 155.2,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 0.0,
#      'solarradiation': 699.0,
#      'solarenergy': 2.5,
#      'uvindex': 7.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1654941600,
#      'temp': 24.9,
#      'feelslike': 24.9,
#      'humidity': 40.32,
#      'dew': 10.5,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.5,
#      'windspeed': 3.6,
#      'winddir': 158.5,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 22.6,
#      'solarradiation': 805.0,
#      'solarenergy': 2.9,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1654945200,
#      'temp': 26.0,
#      'feelslike': 26.0,
#      'humidity': 35.8,
#      'dew': 9.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 13.0,
#      'windspeed': 5.0,
#      'winddir': 168.9,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 48.1,
#      'solarradiation': 869.0,
#      'solarenergy': 3.1,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1654948800,
#      'temp': 26.3,
#      'feelslike': 26.3,
#      'humidity': 33.55,
#      'dew': 9.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.5,
#      'windspeed': 6.1,
#      'winddir': 219.4,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 91.5,
#      'solarradiation': 885.0,
#      'solarenergy': 3.2,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1654952400,
#      'temp': 26.8,
#      'feelslike': 26.4,
#      'humidity': 33.69,
#      'dew': 9.5,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.5,
#      'windspeed': 5.0,
#      'winddir': 227.2,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 79.2,
#      'solarradiation': 858.0,
#      'solarenergy': 3.1,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1654956000,
#      'temp': 27.1,
#      'feelslike': 26.6,
#      'humidity': 33.1,
#      'dew': 9.5,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.2,
#      'windspeed': 4.0,
#      'winddir': 224.0,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 81.5,
#      'solarradiation': 787.0,
#      'solarenergy': 2.8,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1654959600,
#      'temp': 27.2,
#      'feelslike': 26.6,
#      'humidity': 32.47,
#      'dew': 9.3,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.2,
#      'windspeed': 4.7,
#      'winddir': 253.7,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 76.1,
#      'solarradiation': 583.0,
#      'solarenergy': 2.1,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1654963200,
#      'temp': 27.3,
#      'feelslike': 26.7,
#      'humidity': 32.06,
#      'dew': 9.2,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 11.9,
#      'windspeed': 3.6,
#      'winddir': 260.2,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 69.6,
#      'solarradiation': 389.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1654966800,
#      'temp': 27.0,
#      'feelslike': 26.5,
#      'humidity': 31.98,
#      'dew': 8.9,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 10.8,
#      'windspeed': 4.7,
#      'winddir': 284.0,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 60.0,
#      'solarradiation': 160.0,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1654970400,
#      'temp': 25.9,
#      'feelslike': 25.9,
#      'humidity': 39.54,
#      'dew': 11.1,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 20.9,
#      'windspeed': 9.7,
#      'winddir': 306.5,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 63.1,
#      'solarradiation': 84.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1654974000,
#      'temp': 24.3,
#      'feelslike': 24.3,
#      'humidity': 47.7,
#      'dew': 12.5,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 20.5,
#      'windspeed': 3.6,
#      'winddir': 312.5,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 53.7,
#      'solarradiation': 53.0,
#      'solarenergy': 0.2,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1654977600,
#      'temp': 22.9,
#      'feelslike': 22.9,
#      'humidity': 53.98,
#      'dew': 13.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 2.9,
#      'winddir': 310.1,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 44.0,
#      'solarradiation': 5.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1654981200,
#      'temp': 21.0,
#      'feelslike': 21.0,
#      'humidity': 63.04,
#      'dew': 13.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 4.0,
#      'winddir': 307.7,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 34.1,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-06-12',
#    'datetimeEpoch': 1654984800,
#    'tempmax': 29.3,
#    'tempmin': 16.6,
#    'temp': 22.9,
#    'feelslikemax': 27.9,
#    'feelslikemin': 16.6,
#    'feelslike': 22.6,
#    'dew': 12.3,
#    'humidity': 55.7,
#    'precip': 0.0,
#    'precipprob': 9.5,
#    'precipcover': 0.0,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'windgust': 28.8,
#    'windspeed': 13.0,
#    'winddir': 282.4,
#    'pressure': 1020.8,
#    'cloudcover': 56.4,
#    'visibility': 24.1,
#    'solarradiation': 342.5,
#    'solarenergy': 29.5,
#    'uvindex': 9.0,
#    'severerisk': 10.0,
#    'sunrise': '05:19:30',
#    'sunriseEpoch': 1655003970,
#    'sunset': '21:32:49',
#    'sunsetEpoch': 1655062369,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'description': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'stations': None,
#    'source': 'fcst',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1654984800,
#      'temp': 19.4,
#      'feelslike': 19.4,
#      'humidity': 72.82,
#      'dew': 14.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 8.6,
#      'windspeed': 4.0,
#      'winddir': 259.7,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 35.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1654988400,
#      'temp': 17.9,
#      'feelslike': 17.9,
#      'humidity': 78.96,
#      'dew': 14.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.8,
#      'windspeed': 2.2,
#      'winddir': 231.1,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 20.8,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1654992000,
#      'temp': 17.6,
#      'feelslike': 17.6,
#      'humidity': 77.39,
#      'dew': 13.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.1,
#      'windspeed': 3.6,
#      'winddir': 331.5,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 37.2,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1654995600,
#      'temp': 17.6,
#      'feelslike': 17.6,
#      'humidity': 76.39,
#      'dew': 13.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 2.9,
#      'winddir': 289.7,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 61.4,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1654999200,
#      'temp': 17.1,
#      'feelslike': 17.1,
#      'humidity': 80.92,
#      'dew': 13.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 9.0,
#      'windspeed': 4.7,
#      'winddir': 313.2,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 62.5,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1655002800,
#      'temp': 17.0,
#      'feelslike': 17.0,
#      'humidity': 83.58,
#      'dew': 14.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 9.0,
#      'windspeed': 2.5,
#      'winddir': 5.1,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 65.3,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1655006400,
#      'temp': 16.6,
#      'feelslike': 16.6,
#      'humidity': 86.85,
#      'dew': 14.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 4.0,
#      'windspeed': 1.8,
#      'winddir': 359.6,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 57.2,
#      'solarradiation': 8.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1655010000,
#      'temp': 17.3,
#      'feelslike': 17.3,
#      'humidity': 84.7,
#      'dew': 14.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 3.2,
#      'windspeed': 1.8,
#      'winddir': 343.9,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 64.4,
#      'solarradiation': 92.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1655013600,
#      'temp': 18.9,
#      'feelslike': 18.9,
#      'humidity': 78.6,
#      'dew': 15.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.8,
#      'windspeed': 2.9,
#      'winddir': 353.9,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 58.5,
#      'solarradiation': 240.0,
#      'solarenergy': 0.9,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1655017200,
#      'temp': 20.6,
#      'feelslike': 20.6,
#      'humidity': 69.82,
#      'dew': 14.9,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 8.6,
#      'windspeed': 2.9,
#      'winddir': 17.8,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 63.2,
#      'solarradiation': 405.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1655020800,
#      'temp': 22.4,
#      'feelslike': 22.4,
#      'humidity': 62.14,
#      'dew': 14.8,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 8.3,
#      'windspeed': 2.2,
#      'winddir': 358.1,
#      'pressure': 1023.0,
#      'visibility': 24.1,
#      'cloudcover': 56.8,
#      'solarradiation': 565.0,
#      'solarenergy': 2.0,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1655024400,
#      'temp': 24.3,
#      'feelslike': 24.3,
#      'humidity': 56.48,
#      'dew': 15.1,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 7.9,
#      'windspeed': 2.2,
#      'winddir': 358.2,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 50.9,
#      'solarradiation': 704.0,
#      'solarenergy': 2.5,
#      'uvindex': 7.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1655028000,
#      'temp': 26.4,
#      'feelslike': 26.4,
#      'humidity': 41.28,
#      'dew': 12.2,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 8.6,
#      'windspeed': 2.2,
#      'winddir': 266.2,
#      'pressure': 1022.0,
#      'visibility': 24.1,
#      'cloudcover': 56.5,
#      'solarradiation': 812.0,
#      'solarenergy': 2.9,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1655031600,
#      'temp': 27.5,
#      'feelslike': 26.9,
#      'humidity': 34.57,
#      'dew': 10.5,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 16.6,
#      'windspeed': 6.5,
#      'winddir': 257.5,
#      'pressure': 1021.0,
#      'visibility': 24.1,
#      'cloudcover': 61.3,
#      'solarradiation': 877.0,
#      'solarenergy': 3.2,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1655035200,
#      'temp': 28.1,
#      'feelslike': 27.2,
#      'humidity': 32.07,
#      'dew': 9.9,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 20.9,
#      'windspeed': 9.0,
#      'winddir': 260.6,
#      'pressure': 1020.0,
#      'visibility': 24.1,
#      'cloudcover': 78.7,
#      'solarradiation': 899.0,
#      'solarenergy': 3.2,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1655038800,
#      'temp': 28.8,
#      'feelslike': 27.7,
#      'humidity': 30.59,
#      'dew': 9.8,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 23.4,
#      'windspeed': 9.0,
#      'winddir': 274.0,
#      'pressure': 1020.0,
#      'visibility': 24.1,
#      'cloudcover': 48.2,
#      'solarradiation': 873.0,
#      'solarenergy': 3.1,
#      'uvindex': 9.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1655042400,
#      'temp': 29.3,
#      'feelslike': 27.9,
#      'humidity': 27.59,
#      'dew': 8.7,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 21.6,
#      'windspeed': 8.3,
#      'winddir': 279.2,
#      'pressure': 1019.0,
#      'visibility': 24.1,
#      'cloudcover': 56.4,
#      'solarradiation': 801.0,
#      'solarenergy': 2.9,
#      'uvindex': 8.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1655046000,
#      'temp': 29.3,
#      'feelslike': 27.9,
#      'humidity': 26.49,
#      'dew': 8.1,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 27.4,
#      'windspeed': 11.9,
#      'winddir': 289.5,
#      'pressure': 1019.0,
#      'visibility': 24.1,
#      'cloudcover': 49.4,
#      'solarradiation': 690.0,
#      'solarenergy': 2.5,
#      'uvindex': 7.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1655049600,
#      'temp': 28.6,
#      'feelslike': 27.4,
#      'humidity': 28.35,
#      'dew': 8.5,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 28.8,
#      'windspeed': 13.0,
#      'winddir': 290.5,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 53.7,
#      'solarradiation': 548.0,
#      'solarenergy': 2.0,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1655053200,
#      'temp': 27.9,
#      'feelslike': 27.0,
#      'humidity': 30.75,
#      'dew': 9.1,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 28.8,
#      'windspeed': 9.4,
#      'winddir': 305.8,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 30.0,
#      'solarradiation': 389.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1655056800,
#      'temp': 27.1,
#      'feelslike': 26.6,
#      'humidity': 33.33,
#      'dew': 9.6,
#      'precip': 0.0,
#      'precipprob': 4.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 20.9,
#      'windspeed': 8.3,
#      'winddir': 310.2,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 26.3,
#      'solarradiation': 227.0,
#      'solarenergy': 0.8,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1655060400,
#      'temp': 25.3,
#      'feelslike': 25.3,
#      'humidity': 40.97,
#      'dew': 11.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 17.6,
#      'windspeed': 7.6,
#      'winddir': 316.9,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 97.0,
#      'solarradiation': 84.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1655064000,
#      'temp': 23.4,
#      'feelslike': 23.4,
#      'humidity': 48.09,
#      'dew': 11.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.8,
#      'windspeed': 7.9,
#      'winddir': 353.7,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 85.1,
#      'solarradiation': 5.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1655067600,
#      'temp': 22.0,
#      'feelslike': 22.0,
#      'humidity': 55.18,
#      'dew': 12.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 19.1,
#      'windspeed': 9.7,
#      'winddir': 351.1,
#      'pressure': 1018.0,
#      'visibility': 24.1,
#      'cloudcover': 76.7,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-06-13',
#    'datetimeEpoch': 1655071200,
#    'tempmax': 24.6,
#    'tempmin': 16.0,
#    'temp': 20.3,
#    'feelslikemax': 24.6,
#    'feelslikemin': 16.0,
#    'feelslike': 20.3,
#    'dew': 9.3,
#    'humidity': 52.5,
#    'precip': 3.5,
#    'precipprob': 0.0,
#    'precipcover': 16.67,
#    'preciptype': ['rain'],
#    'snow': 0.0,
# ...
#      'solarradiation': 14.7,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 5.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1656025200,
#      'temp': 17.4,
#      'feelslike': 17.4,
#      'humidity': 87.29,
#      'dew': 15.2,
#      'precip': 0.0,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.1,
#      'windspeed': 5.4,
#      'winddir': 306.7,
#      'pressure': 1012.3,
#      'visibility': 20.8,
#      'cloudcover': 100.0,
#      'solarradiation': 7.3,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 5.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1656028800,
#      'temp': 17.2,
#      'feelslike': 17.2,
#      'humidity': 88.03,
#      'dew': 15.2,
#      'precip': 1.8,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 6.8,
#      'windspeed': 5.8,
#      'winddir': 322.4,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 100.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 5.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1656032400,
#      'temp': 16.7,
#      'feelslike': 16.7,
#      'humidity': 89.32,
#      'dew': 14.9,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.0,
#      'windspeed': 5.2,
#      'winddir': 319.5,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 94.0,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 5.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1656036000,
#      'temp': 16.2,
#      'feelslike': 16.2,
#      'humidity': 90.64,
#      'dew': 14.7,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.2,
#      'windspeed': 4.6,
#      'winddir': 316.7,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 88.1,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1656039600,
#      'temp': 15.8,
#      'feelslike': 15.8,
#      'humidity': 91.98,
#      'dew': 14.5,
#      'precip': 1.3,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 4.3,
#      'windspeed': 4.0,
#      'winddir': 313.8,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 82.1,
#      'solarradiation': 0.0,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1656043200,
#      'temp': 16.8,
#      'feelslike': 16.8,
#      'humidity': 88.94,
#      'dew': 15.0,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 5.4,
#      'windspeed': 4.4,
#      'winddir': 268.8,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 82.6,
#      'solarradiation': 33.7,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1656046800,
#      'temp': 17.8,
#      'feelslike': 17.8,
#      'humidity': 86.04,
#      'dew': 15.5,
#      'precip': 0.0,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 4.9,
#      'winddir': 223.8,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 83.2,
#      'solarradiation': 67.3,
#      'solarenergy': 0.2,
#      'uvindex': 1.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1656050400,
#      'temp': 18.9,
#      'feelslike': 18.9,
#      'humidity': 83.26,
#      'dew': 16.0,
#      'precip': 0.1,
#      'precipprob': 9.5,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 7.6,
#      'windspeed': 5.4,
#      'winddir': 178.8,
#      'pressure': 1012.0,
#      'visibility': 24.1,
#      'cloudcover': 83.7,
#      'solarradiation': 101.0,
#      'solarenergy': 0.4,
#      'uvindex': 1.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1656054000,
#      'temp': 20.8,
#      'feelslike': 20.8,
#      'humidity': 74.01,
#      'dew': 16.0,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 9.8,
#      'windspeed': 6.5,
#      'winddir': 191.2,
#      'pressure': 1011.7,
#      'visibility': 24.1,
#      'cloudcover': 58.1,
#      'solarradiation': 241.7,
#      'solarenergy': 0.9,
#      'uvindex': 2.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1656057600,
#      'temp': 22.7,
#      'feelslike': 22.7,
#      'humidity': 65.9,
#      'dew': 16.0,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.1,
#      'windspeed': 7.6,
#      'winddir': 203.5,
#      'pressure': 1011.3,
#      'visibility': 24.1,
#      'cloudcover': 32.6,
#      'solarradiation': 382.3,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1656061200,
#      'temp': 24.6,
#      'feelslike': 24.6,
#      'humidity': 58.77,
#      'dew': 16.0,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.4,
#      'windspeed': 8.6,
#      'winddir': 215.9,
#      'pressure': 1011.0,
#      'visibility': 24.1,
#      'cloudcover': 7.0,
#      'solarradiation': 523.0,
#      'solarenergy': 1.9,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1656064800,
#      'temp': 25.7,
#      'feelslike': 25.7,
#      'humidity': 54.35,
#      'dew': 15.8,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 14.0,
#      'windspeed': 8.6,
#      'winddir': 220.6,
#      'pressure': 1010.3,
#      'visibility': 24.1,
#      'cloudcover': 28.7,
#      'solarradiation': 611.3,
#      'solarenergy': 2.2,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1656068400,
#      'temp': 26.8,
#      'feelslike': 27.3,
#      'humidity': 50.29,
#      'dew': 15.6,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 13.7,
#      'windspeed': 8.6,
#      'winddir': 225.3,
#      'pressure': 1009.7,
#      'visibility': 24.1,
#      'cloudcover': 50.3,
#      'solarradiation': 699.7,
#      'solarenergy': 2.5,
#      'uvindex': 7.0,
#      'severerisk': 30.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1656072000,
#      'temp': 28.0,
#      'feelslike': 28.1,
#      'humidity': 46.56,
#      'dew': 15.5,
#      'precip': 0.0,
#      'precipprob': 23.8,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 13.3,
#      'windspeed': 8.6,
#      'winddir': 230.0,
#      'pressure': 1009.0,
#      'visibility': 24.1,
#      'cloudcover': 72.0,
#      'solarradiation': 788.0,
#      'solarenergy': 2.8,
#      'uvindex': 8.0,
#      'severerisk': 30.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1656075600,
#      'temp': 24.9,
#      'feelslike': 24.9,
#      'humidity': 57.73,
#      'dew': 16.0,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.7,
#      'windspeed': 9.2,
#      'winddir': 180.2,
#      'pressure': 1009.0,
#      'visibility': 24.1,
#      'cloudcover': 81.3,
#      'solarradiation': 588.3,
#      'solarenergy': 2.1,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1656079200,
#      'temp': 21.8,
#      'feelslike': 21.8,
#      'humidity': 71.87,
#      'dew': 16.5,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 12.1,
#      'windspeed': 9.8,
#      'winddir': 130.5,
#      'pressure': 1009.0,
#      'visibility': 24.1,
#      'cloudcover': 90.7,
#      'solarradiation': 388.7,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 3.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1656082800,
#      'temp': 18.8,
#      'feelslike': 18.8,
#      'humidity': 89.86,
#      'dew': 17.1,
#      'precip': 2.4,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 11.5,
#      'windspeed': 10.4,
#      'winddir': 80.7,
#      'pressure': 1009.0,
#      'visibility': 24.1,
#      'cloudcover': 100.0,
#      'solarradiation': 189.0,
#      'solarenergy': 0.7,
#      'uvindex': 2.0,
#      'severerisk': 3.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1656086400,
#      'temp': 18.7,
#      'feelslike': 18.7,
#      'humidity': 90.04,
#      'dew': 17.0,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 13.6,
#      'windspeed': 11.4,
#      'winddir': 111.8,
#      'pressure': 1009.0,
#      'visibility': 20.4,
#      'cloudcover': 87.1,
#      'solarradiation': 184.0,
#      'solarenergy': 0.7,
#      'uvindex': 2.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1656090000,
#      'temp': 18.6,
#      'feelslike': 18.6,
#      'humidity': 90.22,
#      'dew': 16.9,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 15.6,
#      'windspeed': 12.4,
#      'winddir': 142.9,
#      'pressure': 1009.0,
#      'visibility': 16.8,
#      'cloudcover': 74.3,
#      'solarradiation': 179.0,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1656093600,
#      'temp': 18.5,
#      'feelslike': 18.5,
#      'humidity': 90.41,
#      'dew': 16.9,
#      'precip': 0.4,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 17.6,
#      'windspeed': 13.3,
#      'winddir': 174.0,
#      'pressure': 1009.0,
#      'visibility': 13.1,
#      'cloudcover': 61.4,
#      'solarradiation': 174.0,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1656097200,
#      'temp': 17.9,
#      'feelslike': 17.9,
#      'humidity': 92.5,
#      'dew': 16.7,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 22.3,
#      'windspeed': 13.6,
#      'winddir': 169.5,
#      'pressure': 1009.3,
#      'visibility': 14.8,
#      'cloudcover': 74.3,
#      'solarradiation': 125.0,
#      'solarenergy': 0.4,
#      'uvindex': 1.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1656100800,
#      'temp': 17.4,
#      'feelslike': 17.4,
#      'humidity': 94.66,
#      'dew': 16.5,
#      'precip': 0.0,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': None,
#      'windgust': 27.0,
#      'windspeed': 13.8,
#      'winddir': 164.9,
#      'pressure': 1009.7,
#      'visibility': 16.5,
#      'cloudcover': 87.1,
#      'solarradiation': 76.0,
#      'solarenergy': 0.3,
#      'uvindex': 0.0,
#      'severerisk': 3.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1656104400,
#      'temp': 16.9,
#      'feelslike': 16.9,
#      'humidity': 96.87,
#      'dew': 16.4,
#      'precip': 0.8,
#      'precipprob': 19.0,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'preciptype': ['rain'],
#      'windgust': 31.7,
#      'windspeed': 14.0,
#      'winddir': 160.4,
#      'pressure': 1010.0,
#      'visibility': 18.2,
#      'cloudcover': 100.0,
#      'solarradiation': 27.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 3.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'}]}],
#  'alerts': [],
#  'stations': {'ETAR': {'distance': 63117.0,
#    'latitude': 49.43,
#    'longitude': 7.6,
#    'useCount': 0,
#    'id': 'ETAR',
#    'name': 'ETAR',
#    'quality': 50,
#    'contribution': 0.0},
#   'EDDF': {'distance': 64219.0,
#    'latitude': 50.05,
#    'longitude': 8.6,
#    'useCount': 0,
#    'id': 'EDDF',
#    'name': 'EDDF',
#    'quality': 50,
#    'contribution': 0.0},
#   'ETOU': {'distance': 64305.0,
#    'latitude': 50.05,
#    'longitude': 8.33,
#    'useCount': 0,
#    'id': 'ETOU',
#    'name': 'ETOU',
#    'quality': 50,
#    'contribution': 0.0},
#   'EDFM': {'distance': 3839.0,
#    'latitude': 49.47,
#    'longitude': 8.52,
#    'useCount': 0,
#    'id': 'EDFM',
#    'name': 'EDFM',
#    'quality': 29,
#    'contribution': 0.0},
#   'C2091': {'distance': 6493.0,
#    'latitude': 49.469,
#    'longitude': 8.557,
#    'useCount': 0,
#    'id': 'C2091',
#    'name': 'CW2091 Mannheim DE',
#    'quality': 0,
#    'contribution': 0.0}},
#  'currentConditions': {'datetime': '11:20:00',
#   'datetimeEpoch': 1654852800,
#   'temp': 20.0,
#   'feelslike': 20.0,
#   'humidity': 52.5,
#   'dew': 9.9,
#   'precip': 0.0,
#   'precipprob': None,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'preciptype': None,
#   'windgust': None,
#   'windspeed': None,
#   'winddir': None,
#   'pressure': 1024.0,
#   'visibility': 10.0,
#   'cloudcover': 12.3,
#   'solarradiation': 657.0,
#   'solarenergy': 2.4,
#   'uvindex': 7.0,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['ETAR', 'EDDF', 'EDFM'],
#   'sunrise': '05:20:01',
#   'sunriseEpoch': 1654831201,
#   'sunset': '21:31:33',
#   'sunsetEpoch': 1654889493,
#   'moonphase': 0.39}}

# %%
weather_response.keys()
# Out:
# dict_keys(['Köln Hbf', 'München Hbf', 'Mannheim Hbf', 'Stuttgart Hbf', 'Würzburg Hbf', 'Frankfurt(Main)Hbf', 'Nürnberg Hbf', 'Essen Hbf', 'Hamburg Hbf', 'Berlin Hbf', 'Hannover Hbf', 'Hagen Hbf', 'Erfurt Hbf', 'Göttingen'])
